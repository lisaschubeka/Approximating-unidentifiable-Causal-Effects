# %%
# %cd ..
# Out:
# /root/autobounds

# %%
from autobounds.causalProblem import causalProblem
from autobounds.DAG import DAG
from copy import deepcopy

import pandas as pd
import networkx as nx
import plotnine as pn
import numpy as np
import matplotlib.pyplot as plt

# %%
def print_bounds(prog_optim):
    print("==========================")
    (
    print(f"Causal effect lies in the interval [{np.round(prog_optim[0]['dual'], 3)}, "
      f"{np.round(prog_optim[1]['dual'], 3)}]")
    )

# %% [markdown]
# # Section 1: Data

# %% [markdown]
# ## 1.1 Story

# %% [markdown]
# ## 1.2 EDA

# %%
dat = pd.read_csv("replication_files/data/iv.csv")

# %% [markdown]
# # Section 2: Autobounds analysis

# %% [markdown]
# ## 2.1 Draw the DAG, define the problem, load the data

# %%
# Mediation DAG
dag = DAG()
dag.from_structure("Z -> X, X -> Y, Z -> Y, Uxy -> X, Uxy -> Y", unob = "Uxy")
dag.plot()

problem = causalProblem(dag)
problem.load_data(dat)

# %% [markdown]
# ## 2.2 Add assumptions

# %%
problem.add_prob_constraints()

cdeproblem0 = deepcopy(problem)
cdeproblem1 = deepcopy(problem)

# %%
# Bounds for the NDE
nde_problem = deepcopy(problem)
# E(Y(Z=1, X(Z=0)) - Y(Z=0, X(Z=0))
nde_rh_query = nde_problem.query('Y(Z=0)=1')
# To write, lh_query,
# check values of
#     nde_problem.query('X(Z=0)=0') = X00 and X01
#     nde_problem.query('X(Z=0)=1') = X10 and X11
nde_part1 = nde_problem.query('Y(Z=1,X=1)=1')
nde_part2 = nde_problem.query('Y(Z=1,X=0)=1')
nde_lh_query1 = [ x for x in nde_part2 if 'X00' in x[1][0] or 'X01' in x[1][0] ]
nde_lh_query2 = [ x for x in nde_part1 if 'X10' in x[1][0] or 'X11' in x[1][0] ]
nde_query = Query(nde_lh_query1) + Query(nde_lh_query2) - nde_rh_query
nde_problem.set_estimand(nde_query)
nde_problem.write_program().run_couenne()

# Bounds for the NIE
nie_problem = deepcopy(problem)
# E(Y(Z=0, X(Z=1)) - Y(Z=0, X(Z=0))
nie_rh_query = nde_problem.query('Y(Z=0)=1')
# To write, lh_query,
# check values of
#     nie_problem.query('X(Z=1)=0') = X00 and X10
#     nie_problem.query('X(Z=1)=1') = X01 and X11
nie_part1 = nie_problem.query('Y(Z=0,X=1)=1')
nie_part2 = nie_problem.query('Y(Z=0,X=0)=1')
nie_lh_query1 = [ x for x in nie_part2 if 'X00' in x[1][0] or 'X10' in x[1][0] ]
nie_lh_query2 = [ x for x in nie_part1 if 'X01' in x[1][0] or 'X11' in x[1][0] ]
nie_query = Query(nie_lh_query1) + Query(nie_lh_query2) - nie_rh_query
nie_problem.set_estimand(nie_query)
nie_problem.write_program().run_couenne()

# %% [markdown]
# ## 2.3 Encode the estimand

# %%
cde_problem0.set_estimand(
        cde_problem0.query('Y(X=1,Z=0)=1') - 
        cde_problem0.query('Y(X=0,Z=0)=1')
)
cde_problem1.set_estimand(
        cde_problem1.query('Y(X=1,Z=1)=1') - 
        cde_problem1.query('Y(X=0,Z=1)=1')
)

# %% [markdown]
# ## 2.4 Run the program

# %%
# Bounds for CDE, with Z forced to be 0
cde_problem0_optim = cde_problem0.write_program().run_scip()
print_bounds(cde_problem0)
# Bounds for CDE, with Z forced to be 1
cde_problem1_optim = cde_problem1.write_program().run_scip()
print_bounds(cde_problem1)
# Out:
# LOWER BOUND: # -- Primal: -10 / Dual: -128.0 / Time: 0.5 ##
# UPPER BOUND: # -- Primal: -10 / Dual:
0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 144.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 144.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 145.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 145.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 146.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 146.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 147.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 147.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 148.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 148.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 149.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 149.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 150.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 150.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 151.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 151.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 152.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 152.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 153.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 153.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 154.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 154.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 155.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 155.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 156.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 156.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 157.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 157.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 158.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 158.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 159.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 159.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 160.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 160.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 161.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 161.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 162.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 162.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 163.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 163.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 164.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 164.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 165.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 165.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 166.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 166.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 167.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 167.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 168.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 168.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 169.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 169.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 170.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 170.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 171.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 171.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 172.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 172.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 173.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 173.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 174.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 174.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 176.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 175.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 176.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 176.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 178.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 177.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 178.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 178.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 180.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 179.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 181.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 181.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 182.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 182.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 182.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 183.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 184.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 184.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 185.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 185.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 186.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 186.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 187.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 187.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 188.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 188.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 189.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 189.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 190.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 190.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 191.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 191.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 192.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 192.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 193.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 193.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 194.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 194.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 195.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 195.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 196.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 196.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 197.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 197.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 198.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 198.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 199.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 199.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 200.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 200.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 201.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 201.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 202.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 202.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 203.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 203.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 204.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 204.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 205.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 205.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 206.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 206.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 207.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 207.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 208.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 208.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 209.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 209.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 210.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 210.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 211.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 211.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 212.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 212.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 213.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 213.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 214.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 214.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 215.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 215.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 216.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 216.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 217.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 217.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 218.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 218.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 219.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 219.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 220.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 220.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 221.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 221.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 222.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 222.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 223.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 223.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 224.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 224.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 225.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 225.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 226.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 226.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 227.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 227.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 228.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 228.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 229.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 229.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 230.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 230.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 231.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 231.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 232.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 232.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 233.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 233.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 234.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 234.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 235.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 235.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 236.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 236.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 237.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 237.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 238.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 238.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 239.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 239.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 240.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 240.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 241.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 241.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 242.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 242.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 243.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 243.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 244.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 244.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 245.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 245.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 246.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 246.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 247.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 247.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 248.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 248.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 249.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 249.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 250.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 250.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 251.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 251.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 252.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 252.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 253.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 253.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 254.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 254.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 255.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 255.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 256.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 256.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 257.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 257.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 258.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 258.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 259.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 259.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 260.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 260.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 261.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 261.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 262.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 262.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 263.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 263.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# LOWER BOUND: # -- Primal: -10 / Dual: -96.0 / Time: 264.0 ##
# UPPER BOUND: # -- Primal: -10 / Dual: 96.0 / Time: 264.0 ##
# CURRENT THRESHOLDS: # -- Theta: 192.0 / Epsilon: 99999999 ##
# pressed CTRL-C 1 times (5 times for forcing termination)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Bounds for CDE, with Z forced to be 0
# ----> 2 cde_problem0_optim = cde_problem0.write_program().run_scip()
#       3 print_bounds(cde_problem0)
#       4 # Bounds for CDE, with Z forced to be 1
#
# File ~/autobounds/autobounds/Program.py:80, in Program.run_scip(self, verbose, filename, epsilon, theta, maxtime)
#      78 p_lower.start()
#      79 p_upper.start()
# ---> 80 optim_data = parse_bounds_scip(p_lower, p_upper, epsilon = epsilon, theta = theta, maxtime = maxtime)
#      81 return optim_data
#
# File ~/autobounds/autobounds/ProgramUtils.py:273, in parse_bounds_scip(p_lower, p_upper, filename, epsilon, theta, maxtime)
#     271         if time.time() - init_time > maxtime:
#     272             break
# --> 273     time.sleep(1)
#     274 # Checking bounds if problem is finished
#     275 if end_lower == 1 or end_upper == 1:
#
# KeyboardInterrupt:
# pressed CTRL-C 1 times (5 times for forcing termination)

# %% [markdown]
# # Discussion
